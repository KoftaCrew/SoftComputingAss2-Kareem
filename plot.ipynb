# %%
with open("curve_fitting_input.txt") as f:
    input = f.readlines()
    data = []

    # Reading data line by line
    t = int(input[0])
    current_line = 1
    for i in range(t):
        line = input[current_line].split()
        n = int(line[0])
        d = int(line[1])
        current_line += 1

        data_points = []

        for j in range(n):
            line = input[current_line].split()
            x = float(line[0])
            y = float(line[1])
            current_line += 1
            data_points.append((x, y))
        data.append(data_points)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Plot scatter plot
def plotScatter(data):
    x = [i[0] for i in data]
    y = [i[1] for i in data]
    plt.scatter(x, y, color='red')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Scatter plot')
    plt.show()

# %%
# Plot polynomial
def plotPolynomial(data, polynomial):
    x = [i[0] for i in data]
    y = [i[1] for i in data]
    plt.scatter(x, y, color='red')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Polynomial plot')
    x = np.linspace(min(x), max(x), 100)
    y = np.polyval(polynomial, x)
    plt.plot(x, y)
    plt.show()

# %%
generatedCoefficients = [
    [0.4291632061241452, 1.1848745131404204, -0.7179666256608662, 0.08543006396312815],
    [0.5275560396063922, -0.1471444124173649, 1.2477430758640278, -0.8736811020867223, 0.18667174321182056, -0.012552505901797292],
    [3.2673714339762205, -9.98604132527439, 2.647281216479926, 4.883506069791153, -2.9624009176441417, 0.5756932641069809, -0.037063371480910594],
    [0.7784281965959532, 0.27865437411948263, -0.16255111712363954, -0.03659342919805249, 0.008828847130154716],
    [9.085897836405717, 9.551977176629771, 9.910728665123008, 9.864635327874845, 4.136772235739025, -5.888784077751611, -7.296633951814996, -2.962204108258953, 3.5011623571630643, -0.7709076508847758, 0.0511631247288763],
]

# %%
for i in range(5):
    plotPolynomial(data[i], generatedCoefficients[i][::-1])
